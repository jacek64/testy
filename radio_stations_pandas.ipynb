# %%
import pandas as pd

# %%
a = pd.read_table('stations-2016-04-20.rsd', sep='\t',  header=None)

# %%
a.head(10)
# Out:
#                                0   \
# 0                         ﻿WeFunk
# 1   BigUpRadio Slamming Dancehall
# 2                      SteelRadio
# 3    Elite Syncopations - Ragtime
# 4          Radio Formula Acapulco
# 5       WKCR 89.9 FM New York, NY
# 6  WKHR 91.5 FM Chagrin Falls, OH
# 7  CFMU 93.3 FM Hamilton, Ontario
# 8                            WSKT
# 9      WMBR 88.1 FM Cambridge, MA
#
#                                                   1                   2   \
# 0  Raw uncut deedp funk, quality underground hip-...         Rap/Hip Hop
# 1         Station "Slamming Dancehall" of BigUpRadio       Island-Reggae
# 2  We feature the best Steel Players from around ...             Country
# 3  Ragtime - From classic and novelty rags to str...                Jazz
# 4                         Comercial, news and musik.           Talk-News
# 5      The Original FM 89.9 from Columbia University            Eclectic
# ...

# %%
a.tail(10)
# Out:
#                                         0   \
# 32754           Antyradio - Made in Poland
# 32755                   Antyradio - Covers
# 32756                 Antyradio - Greatest
# 32757                Antyradio - Unplugged
# 32758  śląskieradio.pl - Berni-Radio Śląsk
# 32759                          DiscoFm.net
# 32760                            EstacjaFM
# 32761                           Hits & Fun
# 32762     Radio Punto 7 Puerto Montt 101.9
# 32763               Radio Bio Bio Santiago
#
#                                                       1                  2   \
# 32754                                                  -               Rock
# 32755                                                  -               Rock
# 32756                                                  -               Rock
# 32757                                                  -    Rock-Hard/Metal
# 32758                                                  -          Community
# ...
